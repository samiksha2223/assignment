# %%
import numpy as np
import statistics as stat
import scipy.stats as stats
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
# z value for 90% confidence interval
print('Z score for 60% Conifidence Intervla =',np.round(stats.norm.ppf(.05),4))
# Out:
# Z score for 60% Conifidence Intervla = -1.6449

# %%
# z value for 94% confidence interval
print('Z score for 60% Conifidence Intervla =',np.round(stats.norm.ppf(.03),4))
# Out:
# Z score for 60% Conifidence Intervla = -1.8808

# %%
# z value for 60% confidence interval
print('Z score for 60% Conifidence Intervla =',np.round(stats.norm.ppf(.2),4))
# Out:
# Z score for 60% Conifidence Intervla = -0.8416

# %%
# t score for 95% confidence interval
print('T score for 95% Confidence Interval =',np.round(stats.t.ppf(0.025,df=24),4))
# Out:
# T score for 95% Confidence Interval = -2.0639

# %%
# t value for 94% confidence interval
print('T score for 94% Confidence Inteval =',np.round(stats.t.ppf(0.03,df=24),4))
# Out:
# T score for 94% Confidence Inteval = -1.974

# %%
# t value for 99% Confidence Interval
print('T score for 95% Confidence Interval =',np.round(stats.t.ppf(0.005,df=24),4))
# Out:
# T score for 95% Confidence Interval = -2.7969

# %% [markdown]
# # Q. 24

# %%
x_bar = 260
pop_mean = 270

# %%
t_value = (260-270)/(90/np.sqrt(18))
t_value
# Out:
# -0.4714045207910317

# %%
1-stats.t.cdf(abs(t_value),df = 17)
# Out:
# 0.32167253567098353

# %% [markdown]
# # Q. 20

# %%
q20 = pd.read_csv("downloads/cars.csv")

# %%
q20
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
from scipy import stats

# %%
q20.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
Prob_MPG_greater_than_38 = np.round(1 - stats.norm.cdf(38, loc= q20.MPG.mean(), scale= q20.MPG.std()),3)
print('P(MPG>38)=',Prob_MPG_greater_than_38)
# Out:
# P(MPG>38)= 0.348

# %%
prob_MPG_less_than_40 = np.round(stats.norm.cdf(40, loc = q20.MPG.mean(), scale = q20.MPG.std()),3)
print('P(MPG<40)=',prob_MPG_less_than_40)
# Out:
# P(MPG<40)= 0.729

# %%
prob_MPG_greater_than_20 = np.round(1-stats.norm.cdf(20, loc = q20.MPG.mean(), scale = q20.MPG.std()),3)
print('p(MPG>20)=',(prob_MPG_greater_than_20))
# Out:
# p(MPG>20)= 0.943

# %%
prob_MPG_less_than_50 = np.round(stats.norm.cdf(50, loc = q20.MPG.mean(), scale = q20.MPG.std()),3)
print('P(MPG<50)=',(prob_MPG_less_than_50))
# Out:
# P(MPG<50)= 0.956

# %%
prob_MPG_greaterthan20_and_lessthan50= (prob_MPG_less_than_50) - (prob_MPG_greater_than_20)
print('P(20<MPG<50)=',(prob_MPG_greaterthan20_and_lessthan50))
# Out:
# P(20<MPG<50)= 0.013000000000000012

# %% [markdown]
# # Q.9

# %%
q9_a = pd.read_csv("downloads/Q9_a.csv")

# %%
q9_a
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
print('For Cars Speed', "Skewness value=", np.round(q9_a.speed.skew(),2), 'and' , 'Kurtosis value=', np.round(q9_a.speed.kurt(),2))
# Out:
# For Cars Speed Skewness value= -0.12 and Kurtosis value= -0.51

# %%
print('Skewness value =', np.round(q9_a.dist.skew(),2),'and', 'Kurtosis value =', np.round(q9_a.dist.kurt(),2), 'for Cars Distance')
# Out:
# Skewness value = 0.81 and Kurtosis value = 0.41 for Cars Distance

# %%
q9_b = pd.read_csv("downloads/Q9_b.csv")

# %%
q9_b
# Out:
#     Unnamed: 0          SP         WT
# 0            1  104.185353  28.762059
# 1            2  105.461264  30.466833
# 2            3  105.461264  30.193597
# 3            4  113.461264  30.632114
# 4            5  104.461264  29.889149
# ..         ...         ...        ...
# 76          77  169.598513  16.132947
# 77          78  150.576579  37.923113
# 78          79  151.598513  15.769625
# 79          80  167.944460  39.423099
# 80          81  139.840817  34.948615
#
# [81 rows x 3 columns]

# %%
q9_b.rename(columns = {'Unnamed: 0':'Index'}, inplace = True)
q9_b
# Out:
#     Index          SP         WT
# 0       1  104.185353  28.762059
# 1       2  105.461264  30.466833
# 2       3  105.461264  30.193597
# 3       4  113.461264  30.632114
# 4       5  104.461264  29.889149
# ..    ...         ...        ...
# 76     77  169.598513  16.132947
# 77     78  150.576579  37.923113
# 78     79  151.598513  15.769625
# 79     80  167.944460  39.423099
# 80     81  139.840817  34.948615
#
# [81 rows x 3 columns]

# %%
q9_b
# Out:
#     Index          SP         WT
# 0       1  104.185353  28.762059
# 1       2  105.461264  30.466833
# 2       3  105.461264  30.193597
# 3       4  113.461264  30.632114
# 4       5  104.461264  29.889149
# ..    ...         ...        ...
# 76     77  169.598513  16.132947
# 77     78  150.576579  37.923113
# 78     79  151.598513  15.769625
# 79     80  167.944460  39.423099
# 80     81  139.840817  34.948615
#
# [81 rows x 3 columns]

# %%
print('For SP Skewness =', np.round(q9_b.SP.skew(),2), 'kurtosis =', np.round(q9_b.SP.kurt(),2))
# Out:
# For SP Skewness = 1.61 kurtosis = 2.98

# %%
print('For WT Skewness =', np.round(q9_b.WT.skew(),2), 'Kurtosis =', np.round(q9_b.WT.kurt(),2))
# Out:
# For WT Skewness = -0.61 Kurtosis = 0.95

# %% [markdown]
# # Q.21

# %%
dataset = pd.read_csv("downloads/Cars.csv")

# %%
dataset
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

mean, cov = [0, 0], [(1, .6), (.6, 1)]
x, y = np.random.multivariate_normal(mean, cov, 100).T
y += x + 1

f, ax = plt.subplots(figsize=(6, 6))

ax.scatter(x, y, c=".3")
ax.set(xlim=(-3, 3), ylim=(-3, 3))

# Plot your initial diagonal line based on the starting
# xlims and ylims.
diag_line, = ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")

def on_change(axes):
    # When this function is called it checks the current
    # values of xlim and ylim and modifies diag_line
    # accordingly.
    x_lims = ax.get_xlim()
    y_lims = ax.get_ylim()
    diag_line.set_data(x_lims, y_lims)

# Connect two callbacks to your axis instance.
# These will call the function "on_change" whenever
# xlim or ylim is changed.
ax.callbacks.connect('xlim_changed', on_change)
ax.callbacks.connect('ylim_changed', on_change)

plt.show()

# %%
plt.hist(dataset["MPG"], bins = 20, edgecolor=  'black')
plt.show()

# %%
plt.boxplot(x= 'MPG', data =dataset)
plt.show()

# %%
import statsmodels.api as sm
sm.qqplot(dataset['MPG'])
plt.xlabel('MPG', color ='red')
plt.savefig('MPG of cars.png')
plt.show()

# %%
import scipy.stats as stats
stats.probplot(dataset['MPG'], dist="norm", plot=plt)
plt.xlabel('MPG', color ='black')
plt.savefig('MPG of cars.png')
plt.show()

# %%
sn.distplot(dataset['MPG'],kde=True, bins =10)
plt.show()
# Out:
# C:\Users\Baheti's\AppData\Local\Temp\ipykernel_15284\4118575988.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(dataset['MPG'],kde=True, bins =10)

# %%
dataset = pd.read_csv("downloads/wc-at.csv")

# %%
dataset
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
plt.hist(dataset['Waist'], edgecolor= 'red')
plt.show()

# %%
plt.boxplot(x = 'Waist', data= dataset)
plt.title("Waist")
plt.savefig('Waist.png')
plt.show()

# %%
sn.distplot(dataset['Waist'], 
             bins=10,
            kde = True
            )
plt.show()
# Out:
# C:\Users\Baheti's\AppData\Local\Temp\ipykernel_15284\811969127.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(dataset['Waist'],

# %%
import statsmodels.api as sm
sm.qqplot(dataset['Waist'])
plt.show()

# %%
stats.probplot(dataset['Waist'], dist = 'norm', plot = plt)
plt.xlabel('Waist', color= 'red')
plt.savefig('Waist.png')
plt.show()

# %%
sn.distplot(dataset['AT'], bins =10, kde=True)
plt.show()
# Out:
# C:\Users\Baheti's\AppData\Local\Temp\ipykernel_15284\1527809882.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(dataset['AT'], bins =10, kde=True)

# %%
import statsmodels.api as sm
sm.qqplot(dataset['AT'])
plt.show()

# %%
stats.probplot(dataset['AT'], dist = 'norm', plot = plt)
plt.xlabel('AT', color= 'red')
plt.savefig('AT.png')
plt.show()

# %% [markdown]
# # Q.7

# %%
dataset = pd.read_csv("downloads/Q7 (1).csv")

# %%
dataset
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
dataset.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000

# %%
stat.median(dataset["Points"])
# Out:
# 3.6950000000000003

# %%
dataset.mode()
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0           AMC Javelin    3.07   3.44  17.02
# 1    Cadillac Fleetwood    3.92    NaN  18.90
# 2            Camaro Z28     NaN    NaN    NaN
# 3     Chrysler Imperial     NaN    NaN    NaN
# 4            Datsun 710     NaN    NaN    NaN
# 5      Dodge Challenger     NaN    NaN    NaN
# 6            Duster 360     NaN    NaN    NaN
# 7          Ferrari Dino     NaN    NaN    NaN
# 8              Fiat 128     NaN    NaN    NaN
# 9             Fiat X1-9     NaN    NaN    NaN
# 10       Ford Pantera L     NaN    NaN    NaN
# 11          Honda Civic     NaN    NaN    NaN
# 12       Hornet 4 Drive     NaN    NaN    NaN
# 13    Hornet Sportabout     NaN    NaN    NaN
# 14  Lincoln Continental     NaN    NaN    NaN
# 15         Lotus Europa     NaN    NaN    NaN
# 16        Maserati Bora     NaN    NaN    NaN
# 17            Mazda RX4     NaN    NaN    NaN
# 18        Mazda RX4 Wag     NaN    NaN    NaN
# ...

# %%
stat.mode(dataset['Points'])
# Out:
# 3.92

# %%
stat.mode(dataset['Score'])
# Out:
# 3.44

# %%
stat.mode(dataset['Weigh'])
# Out:
# 17.02

# %%
dataset.rename(columns={'Unnamed: 0':'Cars'}, inplace = True)

# %%
dataset
# Out:
#                    Cars  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
dataset.set_index(('Cars'), inplace = True)

# %%
dataset
# Out:
#                      Points  Score  Weigh
# Cars
# Mazda RX4              3.90  2.620  16.46
# Mazda RX4 Wag          3.90  2.875  17.02
# Datsun 710             3.85  2.320  18.61
# Hornet 4 Drive         3.08  3.215  19.44
# Hornet Sportabout      3.15  3.440  17.02
# Valiant                2.76  3.460  20.22
# Duster 360             3.21  3.570  15.84
# Merc 240D              3.69  3.190  20.00
# Merc 230               3.92  3.150  22.90
# Merc 280               3.92  3.440  18.30
# Merc 280C              3.92  3.440  18.90
# Merc 450SE             3.07  4.070  17.40
# Merc 450SL             3.07  3.730  17.60
# Merc 450SLC            3.07  3.780  18.00
# Cadillac Fleetwood     2.93  5.250  17.98
# Lincoln Continental    3.00  5.424  17.82
# Chrysler Imperial      3.23  5.345  17.42
# Fiat 128               4.08  2.200  19.47
# Honda Civic            4.93  1.615  18.52
# Toyota Corolla         4.22  1.835  19.90
# Toyota Corona          3.70  2.465  20.01
# ...

# %%
plt.hist(dataset["Points"], bins = 10, edgecolor= 'black')
plt.show()

# %%
plt.boxplot(x = 'Points', data = dataset)
plt.xlabel('Points')
plt.ylabel('Density')
plt.savefig("PointsInferences.png")
plt.show()

# %%
plt.hist(dataset["Score"], bins = 20, edgecolor = 'y')
plt.show()

# %%
plt.boxplot(x = 'Score', data= dataset)
plt.xlabel('Scores')
plt.ylabel('Density')
plt.savefig("ScoresInferences.png")
plt.show()

# %%
plt.hist(dataset["Weigh"], bins=20, edgecolor = 'yellow')
plt.show()

# %%
plt.boxplot(x= "Weigh", data = dataset)
plt.xlabel('Weigh')
plt.ylabel('Density')
plt.savefig("WeighInferences.png")
plt.show()
